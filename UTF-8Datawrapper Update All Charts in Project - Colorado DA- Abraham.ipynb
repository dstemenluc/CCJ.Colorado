# %% [markdown]
# # Script to Update All Charts in Datawrapper

# %%
python -mpip install datawrapper
# Out:
#   Cell In[5], line 1
#     python -m pip install datawrapper
#               ^
# SyntaxError: invalid syntax

# %%
from datawrapper import Datawrapper
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from datawrapper import Datawrapper
#
# ModuleNotFoundError: No module named 'datawrapper'

# %%
access_token = ""

# %%
dw = Datawrapper(access_token = access_token )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 dw = Datawrapper(access_token = access_token )
#
# NameError: name 'Datawrapper' is not defined

# %%
folder_list = dw.get_folders()

# %% [markdown]
# ### Run this script

# %%
all_chart_folders = ['JD20',
'JD1',
'JD2',
'JD5',
'JD6',
'JD8',
'JD18',
'JD7',
'JD3',
'JD10',
'JD12',
'JD17',
'JD21',
'JD9',
'JD11',
'JD19',
'JD22']

for item in folder_list['list']:
    try:
        if item['name'] == 'Colorado':
            for folder in item['folders'][0]['folders']:
                if folder['name'] in all_charts:
                    print(folder['name'])
                    for fold in folder['folders']:
                        print(fold['name'])
                        for y in fold['charts']:
                            print(y['id'])
                            ############################
                            # Update chart based on id #
                            ############################
                            #chart_ids.append(chart['id'])
                            #dw.refresh_data(chart['id'])
                        

           
    except:
        pass
